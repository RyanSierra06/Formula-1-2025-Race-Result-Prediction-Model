# %%
import pandas as pd
matches = pd.read_csv('/Belgium_2023_grandprix (Sprint Weekend)/Belgium_2023_grandprix_results_data.csv', index_col=0)
matches
# Out:
#                     driver_name        team_name  Practice 1_position  \
# driver_number
# 1                Max Verstappen  Red Bull Racing                  NaN
# 2                Logan Sargeant         Williams                 17.0
# 3              Daniel Ricciardo       AlphaTauri                  9.0
# 4                  Lando Norris          McLaren                  3.0
# 10                 Pierre Gasly           Alpine                 19.0
# 11                 Sergio Perez  Red Bull Racing                  5.0
# 14              Fernando Alonso     Aston Martin                 11.0
# 16              Charles Leclerc          Ferrari                  4.0
# 18                 Lance Stroll     Aston Martin                 18.0
# 20              Kevin Magnussen     Haas F1 Team                  8.0
# 22                 Yuki Tsunoda       AlphaTauri                  7.0
# 23              Alexander Albon         Williams                  6.0
# ...

# %%
import pandas as pd
matches = pd.read_csv('Australia_2023_grandprix (Grandprix Weekend)/Australia_2023_grandprix_results_data.csv', index_col=0)
matches
# Out:
#                    driver_name        team_name  Practice 1_position  \
# driver_number
# 1               Max Verstappen  Red Bull Racing                    1
# 2               Logan Sargeant         Williams                   14
# 4                 Lando Norris          McLaren                    7
# 10                Pierre Gasly           Alpine                    8
# 11                Sergio Perez  Red Bull Racing                    3
# 14             Fernando Alonso     Aston Martin                    4
# 16             Charles Leclerc          Ferrari                    5
# 18                Lance Stroll     Aston Martin                   10
# 20             Kevin Magnussen     Haas F1 Team                   19
# 21               Nyck De Vries       AlphaTauri                   13
# 22                Yuki Tsunoda       AlphaTauri                   16
# 23             Alexander Albon         Williams                   10
# ...
